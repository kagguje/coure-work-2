# %% [markdown]
# <a href="https://colab.research.google.com/github/kagguje/coure-work-2/blob/main/02_wrong_runtime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
import sys
assert sys.version_info.major == 3, "Notebook expects Python 3, but the course uses Python 3"

# %% [markdown]
# the note expects pyton 2 but its running python 3
