# %% [markdown]
# <a href="https://colab.research.google.com/github/kagguje/coure-work-2/blob/main/01_missing_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
# the unavailable module import was removed

# %% [markdown]
# module attempted to import module that was unavailable
